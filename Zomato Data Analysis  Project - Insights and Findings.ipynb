# %% [markdown]
# <h2 align="center" style="color:green;"><b>Project - Insights and Findings</b></h2>

# %% [markdown]
# ## <span style="color:red"><b>1. What type of restaurant do the majority of customers order from?
# </b></span>

# %%
sns.catplot(x="listed_in(type)",kind="count",data=df)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# #### Majority of customers order from Dining type restaurants

# %% [markdown]
# ## <span style="color:red"><b>2. How many votes has each type of restaurant received from customers?
# </b></span>

# %%
g = sns.catplot(x="listed_in(type)",y="votes",kind="bar",data=df,estimator=np.sum,errorbar=None)
plt.grid(axis="y")

# Add labels on top of bars
ax = g.ax  # Get the axes from the FacetGrid
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type="edge", fontsize=12, color='black', padding=3)
    
plt.show()

# %% [markdown]
# #### Dining type restaurants have received 20363 votings
# #### Other type restaurants have received 9367 votings
# #### Cafes type restaurants have received 6434 votings
# #### Buffet type restaurants have received 3028 votings

# %% [markdown]
# ## <span style="color:red"><b>3. What are the ratings that the majority of restaurants have received??
# </b></span>

# %%
# Create the catplot
g = sns.catplot(x="rate", kind="count", data=df)

# Add labels on top of bars
ax = g.ax  # Get the axes from the FacetGrid
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type="edge", fontsize=12, color='black', padding=3)

# Rotate x-ticks, add grid, and show the plot
plt.xticks(rotation=270)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# #### Majority of restaurants have recieved 3.8 rating

# %%
sns.histplot(df.loc[:,"rate"])
# Out:
# <Axes: xlabel='rate', ylabel='Count'>

# %% [markdown]
# ## <span style="color:red"><b>4. Zomato has observed that most couples order most of their food online. What is their average spending on each order?
# </b></span>

# %%
g = sns.catplot(x="online_order",y="approx_cost(for two people)",kind="bar",data=df,estimator=np.mean,errorbar=None)
plt.grid(axis="y")

# Add labels on top of bars
ax = g.ax  # Get the axes from the FacetGrid
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type="edge", fontsize=12, color='black', padding=3)
    
plt.show()

# %% [markdown]
# #### On an average couple order 510 Rs of food

# %% [markdown]
# ## <span style="color:red"><b>5. Which mode (online or offline) has received the maximum rating?
# </b></span>

# %%
g = sns.catplot(x="online_order",y="rate",kind="bar",data=df,estimator=np.mean,errorbar=None)
plt.grid(axis="y")

# Add labels on top of bars
ax = g.ax  # Get the axes from the FacetGrid
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type="edge", fontsize=12, color='black', padding=3)
    
plt.show()

# %% [markdown]
# #### Online order on an average has received rating of 4 star rating where as offline order has received poor rating of 3 stars

# %% [markdown]
# ## <span style="color:red"><b>6. Which type of restaurant received more offline orders, so that Zomato can provide those customers with some good offers?
# </b></span>

# %%
# Create the catplot
g = sns.catplot(x="listed_in(type)", kind="count", data=df, hue="online_order")

# Add labels on top of bars
ax = g.ax  # Get the axes from the FacetGrid
for container in ax.containers:
    ax.bar_label(container, fmt="%.0f", label_type="edge", fontsize=12, color='black', padding=3)

# Rotate x-ticks, add grid, and show the plot
plt.xticks(rotation=270)
plt.grid(axis="y")
plt.show()

# %% [markdown]
# #### Dining type has received more offline orders

# %% [markdown]
# ## <span style="color:green"><b>END</b></span>
